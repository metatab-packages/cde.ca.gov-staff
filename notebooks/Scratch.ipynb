# %%
# %load_ext autoreload
# %autoreload 2

import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import rowgenerators as rg
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rg.dataframe('https://www3.cde.ca.gov/demo-downloads/staffclass/StaffDemo12.txt#&target_format=tsv')
# Out:
# ---------------------------------------------------------------------------
# RowGeneratorError                         Traceback (most recent call last)
# <ipython-input-13-8b242a163627> in <module>()
# ----> 1 rg.dataframe('https://www3.cde.ca.gov/demo-downloads/staffclass/StaffDemo12.txt#&target_format=tsv')
#
# ~/proj/metatab-dev/metapack-dev/rowgenerators/rowgenerators/core.py in dataframe(url, downloader, *args, **kwargs)
#      36     # Try the generator's dataframe method, if it has one
#      37     try:
# ---> 38         return g.dataframe( *args, **kwargs)
#      39     except AttributeError:
#      40         pass
#
# ~/proj/metatab-dev/metapack-dev/rowgenerators/rowgenerators/generator/csv.py in dataframe(self, limit, *args, **kwargs)
#     121
#     122
# --> 123         raise RowGeneratorError(f"{last_exception} in read_csv: path={self.url.fspath} args={args} kwargs={kwargs}\n")
#     124
#     125
#
# ...

# %%
u= rg.parse_app_url('https://www3.cde.ca.gov/demo-downloads/staffclass/StaffDemo12.txt#target_format=tsv')
u.get_resource().get_target().generator.dataframe()
# Out:
#         AcademicYear    RecID  DistrictCode       CountyName  \
# 0               1213  1320697        175101  ALAMEDA
# 1               1213  1326937        131617  ALAMEDA
# 2               1213  1032706        131617  ALAMEDA
# 3               1213  1282315        131617  ALAMEDA
# 4               1213  1114773        131617  ALAMEDA
# ...              ...      ...           ...              ...
# 332493          1213  1078911       5772686  YOLO
# 332494          1213  1251641       5772686  YOLO
# 332495          1213  1019083       5772686  YOLO
# 332496          1213  1290923       5772686  YOLO
# 332497          1213  1227860       5772686  YOLO
#
#                                              DistrictName GenderCode  \
# 0                                      Pleasanton Unified          F
# 1       California School for the Deaf-Fremont (State ...          F
# 2       California School for the Deaf-Fremont (State ...          F
# ...

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg.reference('StaffCred12').dataframe(sep='\t')
# Out:
# !!!!! () {'sep': '\t', 'dtype': {}, 'parse_dates': True, 'low_memory': False}
#         AcademicYear    RecID  CredentialType  AuthorizationType FileCreated
# 0               1213  1129395              10              100.0  08/30/2017
# 1               1213  1313920              10              180.0  08/30/2017
# 2               1213  1037763              10              180.0  08/30/2017
# 3               1213  1264419              10              330.0  08/30/2017
# 4               1213  1074065              10              200.0  08/30/2017
# ...              ...      ...             ...                ...         ...
# 781638          1213  1222304              10              100.0  08/30/2017
# 781639          1213  1163184              10              100.0  08/30/2017
# 781640          1213  1205545              10              375.0  08/30/2017
# 781641          1213  1140817              90                NaN  08/30/2017
# ...
